-- %%
%python
print('hello')

-- %%
sampledata = [(1, "Mallikarjuna"), (2, "Rajesh"), (3, "Srinivas")]
schema = (int, string )
spark.createDataFrame(sampledata, schema).write.mode("overwrite").saveAsTable("sampledata")
